# %% [markdown]
# Library

# %%
import arxiv
import os
import re
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock
from collections import deque

# %%
download_lock = Lock()
stats = {
    "downloaded": 0, 
    "failed": 0
}

def get_source_all_versions(arxiv_id, save_dir="./sources"):
    os.makedirs(save_dir, exist_ok=True)
    
    client = arxiv.Client()
    versions_downloaded = 0
    latest_version = 0

    try:
        search_base = arxiv.Search(id_list=[arxiv_id])
        base_paper = next(client.results(search_base))

        entry_id_url = base_paper.entry_id
        match = re.search(r'v(\d+)$', entry_id_url)

        if not match:
            latest_version = 1
        else:
            latest_version = int(match.group(1))
        
    except Exception as e:
        print(f"ERROR: No source found for {arxiv_id}: {e}")
        return False
    
    for v in range(1, latest_version + 1):
        versioned_id = f"{arxiv_id}v{v}"

        try:
            search_version = arxiv.Search(id_list=[versioned_id])
            paper_version = next(client.results(search_version))
            
            file_name = f"{versioned_id}.tar.gz"
            print(f"\tDownloading: {file_name}...")

            paper_version.download_source(dirpath=save_dir, filename=file_name)

            versions_downloaded += 1
        except Exception as e:
            print(f"ERROR when downloading {versioned_id}: {e}")
            continue
    
    if versions_downloaded == 0 and latest_version > 0:
        print(f"ERROR: Found v{latest_version} but could not download any versions.")
        return False
    elif versions_downloaded == latest_version:
        print(f"Successfully downloaded: {versions_downloaded} / {latest_version} versions for {arxiv_id}.")
        return True
    return False

def download_single_paper(arxiv_id, save_dir):
    target_dir = os.path.join(save_dir, arxiv_id)
    if os.path.exists(target_dir):
        print(f"Skipped {arxiv_id}: already exists.")
        return (arxiv_id, True)
    
    success = get_source_all_versions(arxiv_id, save_dir)
    
    with download_lock:
        if success:
            stats["downloaded"] += 1
        else:
            stats["failed"] += 1
    
    return (arxiv_id, success)

def download_arxiv_range(start_month, start_id, end_month, end_id, save_dir="./sources", max_parallels=20):
    """
    Download arxiv papers in parallel with sliding window approach
    
    Args:
        start_month: Starting month in format 'YYYY-MM'
        start_id: Starting paper ID number
        end_month: Ending month in format 'YYYY-MM'
        end_id: Ending paper ID number
        save_dir: Directory to save downloaded sources
        max_parallels: Number of parallel download threads (default: 20)
    """

    start_year, start_month = start_month.split('-')
    end_year, end_month = end_month.split('-')

    start_prefix = start_year[2:] + start_month
    end_prefix = end_year[2:] + end_month

    stats["downloaded"] = 0
    stats["failed"] = 0
    
    max_consecutive_failures = 3

    if start_month == end_month:
        print(f"Phase: Downloading all from {start_month} ({start_id} → {end_id})...")
        
        arxiv_ids = [f"{start_prefix}.{current_id:05d}" for current_id in range(start_id, end_id + 1)]
        
        with ThreadPoolExecutor(max_workers=max_parallels) as executor:
            future_to_id = {
                executor.submit(download_single_paper, arxiv_id, save_dir): arxiv_id 
                for arxiv_id in arxiv_ids
            }
            
            completed = 0
            for future in as_completed(future_to_id):
                arxiv_id = future_to_id[future]
                completed += 1
                
                try:
                    paper_id, success = future.result()
                    print(f"[{completed}/{len(arxiv_ids)}] {paper_id}")
                except Exception as e:
                    print(f"[{completed}/{len(arxiv_ids)}] {arxiv_id} - Exception: {e}")
                    with download_lock:
                        stats["failed"] += 1
        
        print(f"Finished {start_month}.\n")
    else:
        # Phase 1: Download from start_month with sliding window
        print(f"Phase 1: Downloading from {start_month} starting at ID {start_id}...")
        
        current_id = start_id
        failed_consecutive = 0
        completed_count = 0
        
        with ThreadPoolExecutor(max_workers=max_parallels) as executor:
            active_futures = {}
            results_buffer = {} 
            next_id_to_process = start_id
            
            while failed_consecutive < max_consecutive_failures:
                while len(active_futures) < max_parallels and failed_consecutive < max_consecutive_failures:
                    arxiv_id = f"{start_prefix}.{current_id:05d}"
                    future = executor.submit(download_single_paper, arxiv_id, save_dir)
                    active_futures[future] = (arxiv_id, current_id)
                    current_id += 1
                
                if active_futures:
                    for done_future in as_completed(list(active_futures.keys())):
                        arxiv_id, id_num = active_futures.pop(done_future)
                        
                        try:
                            paper_id, success = done_future.result()
                            results_buffer[id_num] = (paper_id, success)
                        except Exception as e:
                            print(f"X {arxiv_id} - Exception: {e}")
                            results_buffer[id_num] = (arxiv_id, False)
                        
                        while next_id_to_process in results_buffer:
                            paper_id, success = results_buffer.pop(next_id_to_process)
                            completed_count += 1
                            print(f"[Phase 1: {completed_count}] {paper_id}")
                            
                            if success:
                                failed_consecutive = 0
                            else:
                                failed_consecutive += 1
                            
                            next_id_to_process += 1
                            
                            if failed_consecutive >= max_consecutive_failures:
                                print(f"\nReached {max_consecutive_failures} consecutive failures.")
                                for remaining_future in active_futures.keys():
                                    remaining_future.cancel()
                                active_futures.clear()
                                break

                        if failed_consecutive >= max_consecutive_failures:
                            break

                if not active_futures and failed_consecutive < max_consecutive_failures:
                    break

        
        print(f"Completed {start_month}. No more papers found after {max_consecutive_failures} consecutive failures.\n")
        
        # Phase 2: Download from end_month
        print(f"Phase 2: Downloading from {end_month} starting at ID 1, going forward to ID {end_id}...")
        
        phase2_ids = [f"{end_prefix}.{current_id:05d}" for current_id in range(1, end_id + 1)]
        
        with ThreadPoolExecutor(max_workers=max_parallels) as executor:
            future_to_id = {
                executor.submit(download_single_paper, arxiv_id, save_dir): arxiv_id 
                for arxiv_id in phase2_ids
            }
            
            completed = 0
            for future in as_completed(future_to_id):
                arxiv_id = future_to_id[future]
                completed += 1
                
                try:
                    paper_id, success = future.result()
                    print(f"[Phase 2: {completed}/{len(phase2_ids)}] {paper_id}")
                except Exception as e:
                    print(f"[Phase 2: {completed}/{len(phase2_ids)}] {arxiv_id} - Exception: {e}")
                    with download_lock:
                        stats["failed"] += 1
        
        print(f"Reached end ID {end_id} in {end_month}.")
        
        print(f"\n{'='*50}")
        print(f"Download complete!")
        print(f"Successfully downloaded: {stats['downloaded']} papers")
        print(f"Files saved to: {os.path.abspath(save_dir)}")

download_arxiv_range(
    start_month="2023-05",
    start_id=9595,
    end_month="2023-05", 
    end_id=14596,
    save_dir="./sources"
)
# Out:
# Phase: Downloading all from 05 (9595 → 14596)...
# 	Downloading: 2305.09595v1.tar.gz...
# 	Downloading: 2305.09605v1.tar.gz...
# 	Downloading: 2305.09600v1.tar.gz...
# 	Downloading: 2305.09603v1.tar.gz...
# 	Downloading: 2305.09606v1.tar.gz...
# 	Downloading: 2305.09607v1.tar.gz...
# 	Downloading: 2305.09613v1.tar.gz...
# 	Downloading: 2305.09598v1.tar.gz...
# 	Downloading: 2305.09614v1.tar.gz...
# 	Downloading: 2305.09599v1.tar.gz...
# 	Downloading: 2305.09601v1.tar.gz...
# 	Downloading: 2305.09609v1.tar.gz...
# 	Downloading: 2305.09596v1.tar.gz...
# 	Downloading: 2305.09611v1.tar.gz...
# 	Downloading: 2305.09602v1.tar.gz...
# 	Downloading: 2305.09608v1.tar.gz...
# 	Downloading: 2305.09604v1.tar.gz...
# 	Downloading: 2305.09612v1.tar.gz...
# 	Downloading: 2305.09610v1.tar.gz...
# 	Downloading: 2305.09597v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09609.
# Successfully downloaded: 1 / 1 versions for 2305.09613.
# Successfully downloaded: 1 / 1 versions for 2305.09604.
# Successfully downloaded: 1 / 1 versions for 2305.09603.
# Successfully downloaded: 1 / 1 versions for 2305.09608.
# Successfully downloaded: 1 / 1 versions for 2305.09598.
# Successfully downloaded: 1 / 1 versions for 2305.09612.
# Successfully downloaded: 1 / 1 versions for 2305.09607.
# Successfully downloaded: 1 / 1 versions for 2305.09597.
# Successfully downloaded: 1 / 1 versions for 2305.09610.
# Successfully downloaded: 1 / 1 versions for 2305.09596.
# Successfully downloaded: 1 / 1 versions for 2305.09600.
# Successfully downloaded: 1 / 1 versions for 2305.09602.
# 	Downloading: 2305.09605v2.tar.gz...
# 	Downloading: 2305.09599v2.tar.gz...
# 	Downloading: 2305.09611v2.tar.gz...
# 	Downloading: 2305.09595v2.tar.gz...
# 	Downloading: 2305.09614v2.tar.gz...
# 	Downloading: 2305.09601v2.tar.gz...
# 	Downloading: 2305.09606v2.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09614.
# 	Downloading: 2305.09616v1.tar.gz...
# 	Downloading: 2305.09615v1.tar.gz...
# 	Downloading: 2305.09617v1.tar.gz...
# 	Downloading: 2305.09618v1.tar.gz...
# 	Downloading: 2305.09620v1.tar.gz...
# 	Downloading: 2305.09619v1.tar.gz...
# 	Downloading: 2305.09623v1.tar.gz...
# 	Downloading: 2305.09621v1.tar.gz...
# 	Downloading: 2305.09622v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09611.
# 	Downloading: 2305.09624v1.tar.gz...
# 	Downloading: 2305.09625v1.tar.gz...
# 	Downloading: 2305.09626v1.tar.gz...
# 	Downloading: 2305.09627v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09617.
# 	Downloading: 2305.09595v3.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09599.
# Successfully downloaded: 1 / 1 versions for 2305.09619.
# Successfully downloaded: 1 / 1 versions for 2305.09626.
# Successfully downloaded: 1 / 1 versions for 2305.09621.
# 	Downloading: 2305.09618v2.tar.gz...
# 	Downloading: 2305.09628v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09618.
# 	Downloading: 2305.09622v2.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09628.
# 	Downloading: 2305.09629v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09622.
# Successfully downloaded: 1 / 1 versions for 2305.09615.
# 	Downloading: 2305.09601v3.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09629.
# 	Downloading: 2305.09616v2.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09627.
# 	Downloading: 2305.09630v1.tar.gz...
# 	Downloading: 2305.09595v4.tar.gz...
# Successfully downloaded: 4 / 4 versions for 2305.09595.
# 	Downloading: 2305.09631v1.tar.gz...
# 	Downloading: 2305.09632v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09624.
# 	Downloading: 2305.09634v1.tar.gz...
# 	Downloading: 2305.09633v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09632.
# 	Downloading: 2305.09635v1.tar.gz...
# 	Downloading: 2305.09636v1.tar.gz...
# 	Downloading: 2305.09601v4.tar.gz...
# 	Downloading: 2305.09637v1.tar.gz...
# 	Downloading: 2305.09638v1.tar.gz...
# 	Downloading: 2305.09616v3.tar.gz...
# 	Downloading: 2305.09639v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09636.
# Successfully downloaded: 1 / 1 versions for 2305.09625.
# 	Downloading: 2305.09640v1.tar.gz...
# 	Downloading: 2305.09620v2.tar.gz...
# Successfully downloaded: 3 / 3 versions for 2305.09616.
# 	Downloading: 2305.09630v2.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09640.
# 	Downloading: 2305.09631v2.tar.gz...
# 	Downloading: 2305.09641v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09630.
# 	Downloading: 2305.09642v1.tar.gz...
# 	Downloading: 2305.09634v2.tar.gz...
# 	Downloading: 2305.09633v2.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09631.
# Successfully downloaded: 2 / 2 versions for 2305.09634.
# 	Downloading: 2305.09635v2.tar.gz...
# 	Downloading: 2305.09601v5.tar.gz...
# 	Downloading: 2305.09637v2.tar.gz...
# 	Downloading: 2305.09638v2.tar.gz...
# 	Downloading: 2305.09643v1.tar.gz...
# 	Downloading: 2305.09639v2.tar.gz...
# Successfully downloaded: 5 / 5 versions for 2305.09601.
# Successfully downloaded: 2 / 2 versions for 2305.09637.
# 	Downloading: 2305.09644v1.tar.gz...
# 	Downloading: 2305.09645v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09639.
# 	Downloading: 2305.09620v3.tar.gz...
# 	Downloading: 2305.09646v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09606.
# 	Downloading: 2305.09605v3.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09646.
# Successfully downloaded: 3 / 3 versions for 2305.09620.
# 	Downloading: 2305.09647v1.tar.gz...
# 	Downloading: 2305.09642v2.tar.gz...
# 	Downloading: 2305.09633v3.tar.gz...
# 	Downloading: 2305.09648v1.tar.gz...
# Successfully downloaded: 3 / 3 versions for 2305.09605.
# Successfully downloaded: 1 / 1 versions for 2305.09647.
# 	Downloading: 2305.09635v3.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09648.
# 	Downloading: 2305.09649v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09642.
# 	Downloading: 2305.09650v1.tar.gz...
# Successfully downloaded: 3 / 3 versions for 2305.09635.
# 	Downloading: 2305.09638v3.tar.gz...
# 	Downloading: 2305.09643v2.tar.gz...
# Successfully downloaded: 3 / 3 versions for 2305.09638.
# 	Downloading: 2305.09644v2.tar.gz...
# 	Downloading: 2305.09645v2.tar.gz...
# 	Downloading: 2305.09651v1.tar.gz...
# 	Downloading: 2305.09652v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09643.
# 	Downloading: 2305.09653v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09645.
# 	Downloading: 2305.09654v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09653.
# 	Downloading: 2305.09655v1.tar.gz...
# 	Downloading: 2305.09656v1.tar.gz...
# 	Downloading: 2305.09633v4.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09654.
# Successfully downloaded: 2 / 2 versions for 2305.09644.
# 	Downloading: 2305.09657v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09655.
# Successfully downloaded: 4 / 4 versions for 2305.09633.
# 	Downloading: 2305.09658v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09657.
# 	Downloading: 2305.09659v1.tar.gz...
# 	Downloading: 2305.09660v1.tar.gz...
# 	Downloading: 2305.09650v2.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09658.
# 	Downloading: 2305.09661v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09660.
# 	Downloading: 2305.09662v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09661.
# 	Downloading: 2305.09652v2.tar.gz...
# 	Downloading: 2305.09663v1.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09652.
# Successfully downloaded: 1 / 1 versions for 2305.09662.
# Successfully downloaded: 2 / 2 versions for 2305.09650.
# 	Downloading: 2305.09664v1.tar.gz...
# 	Downloading: 2305.09665v1.tar.gz...
# 	Downloading: 2305.09656v2.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09665.
# 	Downloading: 2305.09666v1.tar.gz...
# 	Downloading: 2305.09651v2.tar.gz...
# 	Downloading: 2305.09667v1.tar.gz...
# 	Downloading: 2305.09668v1.tar.gz...
# 	Downloading: 2305.09669v1.tar.gz...
# 	Downloading: 2305.09659v2.tar.gz...
# 	Downloading: 2305.09670v1.tar.gz...
# Successfully downloaded: 1 / 1 versions for 2305.09667.
# Successfully downloaded: 1 / 1 versions for 2305.09668.
# Successfully downloaded: 2 / 2 versions for 2305.09659.
# 	Downloading: 2305.09671v1.tar.gz...
# 	Downloading: 2305.09672v1.tar.gz...
# 	Downloading: 2305.09663v2.tar.gz...
# 	Downloading: 2305.09673v1.tar.gz...
# 	Downloading: 2305.09674v1.tar.gz...
# 	Downloading: 2305.09675v1.tar.gz...
# 	Downloading: 2305.09676v1.tar.gz...
# 	Downloading: 2305.09656v3.tar.gz...
# Successfully downloaded: 2 / 2 versions for 2305.09663.
